# %% [markdown]
# # Distplot (Histograms)

# %% [markdown]
# **What is histograms**
#
# A **histogram** is an approximate representation of the distribution of numerical or categorical data.
#
# **Why use histograms?**
# <ol>
#     <li>
#         Histograms are used to show <b>distributions</b> of variables
#     </li>
#     <li>
#         To plot a <b>univariate</b> distribution of observations.
#     </li>
#     <li>
#         To show the underlying <b>frequency distribution</b> of the variable.
#     </li>
# </ol>

# %% [markdown]
# **Let's import all the necessary pacakages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
print('setup complete')
# Out:
# setup complete

# %%
house_df=pd.read_csv('house_price.csv')

# %%
house_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
from scipy.stats import norm

# %%
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'])


plt.show()

# %%
#edit bin parameter
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'],bins=10)


plt.show()

# %%
#draw only kde plot
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'],hist=False)


plt.show()

# %%
#draw only histograms
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'],kde=False)


plt.show()

# %%
#add frequency line
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'],rug=True)


plt.show()

# %%
#use gaussian distribution instead of kde
from scipy.stats import norm
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'],rug=True,fit=norm,kde=False)


plt.show()

# %%
#draw the figure on y axis
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'],rug=True,vertical=True)


plt.show()

# %%
#change color
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'],rug=True,color='y')


plt.show()

# %%
plt.figure(figsize=(15,8))
sns.distplot(house_df['SalePrice'],hist=True,rug=True,
            rug_kws={'color':'b'},
            kde_kws={'color':'g','lw':3},
            hist_kws={'color':'r','histtype':'step','linewidth':3,'alpha':1})
plt.show()

# %% [markdown]
# # Exercise

# %% [markdown]
# Now its your turn to draw distplot yourself. Here I gave you salary data. You need to analyse how the salary is distributed. Don't just draw change the different parameters to see how the plot change(use bins=10). Your plot should look like the image below.
#
# I know you can do it. If you have face difficulty double click the cell that says double click for answer. For further query leave a comment in my youtube video.

# %% [markdown]
# <img src="output.png">

# %%
salary_df=pd.read_csv('salary.csv')

# %%
salary_df.head()
# Out:
#    YearsExperience   salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# <!----------------
#
# plt.figure(figsize=(15,8))
# sns.distplot(salary_df['salary'],rug=True,bins=10)
# plt.show()
#
#
# ----------------->
#
# **Double click for answer**

# %% [markdown]
# # Great work !!!
